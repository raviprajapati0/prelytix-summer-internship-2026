# %% [markdown]
# ## task-1

# %% [markdown]
# ### t1.py

# %%
import numpy as np

np.random.seed(42)

n1=np.random.randint(1,101,(6,6))

print(f"Matrix:\n{n1}")
div_by_3_5=n1[(n1%3==0)&(n1%5==0)]

print(f"Divisible by 3 and 5:{div_by_3_5}")

# %% [markdown]
# ### t2.py

# %%
import numpy as np

np.random.seed(42)

n1=np.random.randint(0,100,10)

avg=n1.mean()

replace_arr=np.where(n1>avg,1,0)

print(f"Original Array:{n1}")
print(f"Mean:{avg}")
print(f"Modified Array:{replace_arr}")

# %% [markdown]
# ### t3.py

# %%
import numpy as np

np.random.seed(42)

n1=np.random.randint(1,100,(5,5))

r=[1,3,4];c=[0,2,4]
n2=n1[np.ix_(r,c)]
print("Original Array:",n1)
print("Sub Array:",n2)

# %% [markdown]
# ### t4.py

# %%
import numpy as np

np.random.seed(42)

n1=np.random.randint(0,100,(4,4))

row_sort=np.sort(n1,axis=1)
col_sort=np.sort(n1,axis=0)

print(n1)
print(row_sort)
print(col_sort)

# %% [markdown]
# ### t5.py

# %%
import numpy as np

np.random.seed(42)

n1=np.random.randint(0,101,15)

score=[n1>=85,n1>=70,n1>=55,n1>=40]
val=['A','B','C','D']

grades=np.select(score,val,default='F')
print(n1)
print(grades)

# %% [markdown]
# ## task-2

# %% [markdown]
# ### t1.py

# %%
import numpy as np

np.random.seed(42)

n1=np.random.randint(0,100,(5,4))
print(n1)
n=np.array([1,2,3,4])
n2=np.array([10,20,30,40,50])[:,np.newaxis]
print(n1+n)
print(n1-n2)

# %% [markdown]
# ### t2.py

# %%
import numpy as np

np.random.seed(42)

n1=np.random.randint(0,100,(6,4))

mn=np.mean(n1,axis=0)
sd=np.std(n1,axis=0)

normalise_arr=(n1-mn)/sd

print("Original:",n1)
print("Normalise:",normalise_arr)

print("Mean:",normalise_arr.mean(),"Standard Deviation:",normalise_arr.std())

# %% [markdown]
# ### t3.py

# %%
import numpy as np

n=np.array([1,2,3,4,5])

ans=np.abs(n[:,np.newaxis]-n)
print(ans)

# %% [markdown]
# ## task-3

# %% [markdown]
# ### t1.py

# %%
import numpy as np

m1 = np.array([
    [2, 1, 1],
    [1, 3, 2],
    [1, 0, 0]
])

print("M1:\n", m1)

inverse = np.linalg.inv(m1)

print("\nInverse of M1:\n", np.round(inverse, 2))

result = m1 @ inverse

rounded_result = np.round(result, 2)

print("\nM1 * inv(M1):\n", rounded_result)

I = np.eye(3)

print(np.allclose(result, I))

# %% [markdown]
# ### t2.py

# %%
import numpy as np

A=np.array([[2,1],[1,3]])

B=np.array([5,10])

x=np.linalg.solve(A,B)

print("Solution:",x)

flag=np.allclose(A@x,B)
print("Verification of solution:",flag)

# %% [markdown]
# ### t3.py

# %%
import numpy as np

A = np.random.randint(1, 10, (3, 3))

print("A:\n", A)

S = A.T @ A

print("\nSymmetric Matrix S:\n", S)

eigenvalues = np.linalg.eigvalsh(S)

print("\nEigenvalues:\n", np.round(eigenvalues, 2))


print(np.all(eigenvalues >= -1e-10))

# %% [markdown]
# ### t4.py

# %%
import numpy as np

v1 = np.random.rand(3)
v2 = np.random.rand(3)

unit_v1 = v1 / np.linalg.norm(v1)
unit_v2 = v2 / np.linalg.norm(v2)

print("Unit Vector 1:\n", np.round(unit_v1, 2))
print("\nUnit Vector 2:\n", np.round(unit_v2, 2))

dot_product = np.dot(unit_v1, unit_v2)

print("\nDot Product:", np.round(dot_product, 2))

# %% [markdown]
# ## task-4

# %% [markdown]
# ### t1.py

# %%
import numpy as np

arr = np.random.randint(1, 100, 20)

print("Array:\n", arr)

sorted_idx = np.argsort(arr)

smallest_idx = sorted_idx[:5]
largest_idx = sorted_idx[-5:]

print("\nIndices of 5 Smallest Values:\n", smallest_idx)
print("Values:\n", arr[smallest_idx])

print("\nIndices of 5 Largest Values:\n", largest_idx)
print("Values:\n", arr[largest_idx])

# %% [markdown]
# ### t2.py

# %%
import numpy as np

arr = np.random.randint(1, 100, (5, 5))

print("Original Matrix:\n", arr)

row_sorted = np.sort(arr, axis=1)

final_matrix = np.sort(row_sorted, axis=0)

print("\nSorted Matrix:\n", final_matrix)

# %% [markdown]
# ### t3.py

# %%
import numpy as np

A = np.random.randint(1, 21, 15)
B = np.random.randint(1, 21, 15)

print("Array A:\n", A)
print("\nArray B:\n", B)

common = np.intersect1d(A, B)
only_A = np.setdiff1d(A, B)
only_B = np.setdiff1d(B, A)

print("\nCommon Elements:\n", common)

print("\nElements Only in A:\n", only_A)

print("\nElements Only in B:\n", only_B)

# %% [markdown]
# ## task-5

# %% [markdown]
# ### t1.py

# %%
from pathlib import Path

import numpy as np

OUTPUT_DIR = Path("outputs")
OUTPUT_DIR.mkdir(exist_ok=True)

arr = np.random.randint(1, 100, 10)

print("Original Array:\n", arr)

npy_path = OUTPUT_DIR / "array_sample.npy"
csv_path = OUTPUT_DIR / "array_sample.csv"

np.save(npy_path, arr)
np.savetxt(csv_path, arr, delimiter=",")

npy_data = np.load(npy_path)
csv_data = np.loadtxt(csv_path, delimiter=",")

print("\nLoaded from .npy:\n", npy_data)
print("\nLoaded from .csv:\n", csv_data)

print("\nAre both arrays equal?")
print(np.allclose(npy_data, csv_data))

# %% [markdown]
# ### t2.py

# %%
from pathlib import Path

import numpy as np

OUTPUT_DIR = Path("outputs")
OUTPUT_DIR.mkdir(exist_ok=True)

marks = np.random.randint(0, 101, (50, 4))

marks_path = OUTPUT_DIR / "marks.csv"
np.savetxt(marks_path, marks, delimiter=",")

data = np.loadtxt(marks_path, delimiter=",")

total = np.sum(data, axis=1)

topper = np.argmax(total)

average = np.mean(data, axis=0)

below50 = np.where(data < 50)[0]

print("Marks:\n", data)

print("\nTopper Index:", topper)

print("\nSubject-wise Average:\n", average)

print("\nStudents Below 50 in Any Subject:\n", np.unique(below50))

# %% [markdown]
# ## task-6

# %% [markdown]
# ### t1.py

# %%
import numpy as np
import time

x = np.random.randint(1, 100, 1000000)

start = time.time()

result = []
for i in range(len(x)):
    result.append(x[i]**2 + 2*x[i] + 1)

end = time.time()

print("Loop Time:", end - start)

start = time.time()

result2 = x**2 + 2*x + 1

end = time.time()

print("Vectorized Time:", end - start)

print("\nSame Result?")
print(np.allclose(result, result2))

# %% [markdown]
# ### t2.py

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

outer1 = np.einsum('i,j->ij', a, b)

outer2 = np.outer(a, b)

print("Using einsum:\n", outer1)

print("\nUsing outer:\n", outer2)

print("\nAre both equal?")
print(np.allclose(outer1, outer2))

# %% [markdown]
# ### t3.py

# %%
import numpy as np
import time

a32 = np.random.rand(1000000).astype(np.float32)
a64 = np.random.rand(1000000).astype(np.float64)

print("Float32 Memory:", a32.nbytes, "bytes")
print("Float64 Memory:", a64.nbytes, "bytes")

start = time.time()
square32 = a32 ** 2
end = time.time()

print("\nFloat32 Squaring Time:", end - start)

start = time.time()
square64 = a64 ** 2
end = time.time()

print("Float64 Squaring Time:", end - start)

# %% [markdown]
# ## main-task

# %% [markdown]
# ### t1.py

# %%
import numpy as np

def stats_report(arr):
    arr = np.array(arr)

    shape = arr.shape
    minimum = np.min(arr)
    maximum = np.max(arr)
    mean = np.mean(arr)
    median = np.median(arr)
    std = np.std(arr)
    p25 = np.percentile(arr, 25)
    p75 = np.percentile(arr, 75)

    max_pos = np.unravel_index(np.argmax(arr), arr.shape)

    print("Shape :", shape)
    print("Minimum :", minimum)
    print("Maximum :", maximum)
    print("Mean :", mean)
    print("Median :", median)
    print("Standard Deviation :", std)
    print("25th Percentile :", p25)
    print("75th Percentile :", p75)
    print("Global Maximum Position (row, col) :", max_pos)

arr = np.array([
    [10, 25, 30],
    [45, 12, 18],
    [7, 60, 22]
])

stats_report(arr)

# %% [markdown]
# ### t2.py

# %%
import numpy as np

img = np.random.randint(0, 256, (100, 100), dtype=np.uint8)

horizontal_flip = np.fliplr(img)

vertical_flip = np.flipud(img)

center_crop = img[30:70, 30:70]

bright_img = np.clip(img.astype(np.int16) + 20, 0, 255).astype(np.uint8)

threshold_img = np.where(img > 128, 255, 0)

print("Original Shape:", img.shape)
print("Center Crop Shape:", center_crop.shape)
print("Threshold Image:\n", threshold_img)

# %% [markdown]
# ### t3.py

# %%
import numpy as np

marks = np.random.randint(35, 101, (30, 5))

avg_marks = np.mean(marks, axis=1)

ranks = avg_marks.argsort()[::-1].argsort() + 1

top_5 = np.argsort(avg_marks)[-5:][::-1]

bottom_5 = np.argsort(avg_marks)[:5]

correlation = np.corrcoef(marks[:, 0], marks[:, 1])

print("Marks:\n", marks)

print("\nAverage Marks Per Student:\n", avg_marks)

print("\nRanks:\n", ranks)

print("\nTop 5 Students Index:\n", top_5)

print("\nBottom 5 Students Index:\n", bottom_5)

print("\nCorrelation Between Subject 1 and Subject 2:\n", correlation)

# %% [markdown]
# ### t5.py

# %%
import numpy as np

returns = np.random.uniform(-0.1, 0.2, (12, 5))

mean_return = np.mean(returns, axis=0)

cov_matrix = np.cov(returns, rowvar=False)

weights = np.array([0.2] * 5)

portfolio_variance = weights @ cov_matrix @ weights

asset_risk = np.std(returns, axis=0)

highest_risk = np.argmax(asset_risk)

lowest_risk = np.argmin(asset_risk)

print("Monthly Returns:\n", returns)

print("\nMean Return Per Asset:\n", mean_return)

print("\nCovariance Matrix:\n", cov_matrix)

print("\nPortfolio Variance:\n", portfolio_variance)

print("\nHighest Risk Asset Index:", highest_risk)

print("Lowest Risk Asset Index:", lowest_risk)
